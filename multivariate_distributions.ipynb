# %% [markdown]
# <a href="https://colab.research.google.com/github/thaopham29/Tales-of-probability-and-risks/blob/main/multivariate_distributions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# # Joint distribution of random variables
#
# ## Definition

# %% [markdown]
# ## Joinly discrete distributed random variables

# %% [markdown]
# ## Joinly continuous distributed random variables

# %% [markdown]
# ## Marginal and conditional distributions

# %% [markdown]
# ## Independent random variables
